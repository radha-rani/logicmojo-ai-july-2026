# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/skarma91/logicmojo-ai-july-2026/blob/main/modules/module-1-python-for-ai/04-the-data-stack/micro-assignment/assignment.ipynb)
#
# # Micro-assignment 1.4: The data stack
#
# Eight problems on NumPy and Pandas (plus earlier topics). The NumPy set comes first, then Pandas. Match each expected output exactly. See `README.md` for full details.
#
# Run the setup cell first.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Problem 1: Array basics
#
# ```
# plus 10: [12 14 16 18 20]
# product: [ 4 10 18]
# mean: 6.0
# ```

# %%
# TODO: create np.array([2, 4, 6, 8, 10]); print it with 10 added to every element.
# Multiply [1, 2, 3] by [4, 5, 6] elementwise and print it. Print the mean of the first array.

# your code here

# %% [markdown]
# ## Problem 2: Above the mean
#
# ```
# mean: 5.33
# above mean: [ 8 10  6]
# count: 3
# ```

# %%
data = np.array([3, 8, 1, 10, 6, 4])

# TODO: compute the mean (print it to two decimals). Use a boolean mask to select
# the elements greater than the mean; print them and how many there are.

# your code here

# %% [markdown]
# ## Problem 3: Vectorized equals loop
#
# ```
# vectorized: 60
# loop: 60
# match: True
# ```

# %%
qty = np.array([2, 1, 3])
price = np.array([10, 25, 5])

# TODO: compute the total spend two ways and show they match.
# 1. Vectorized: np.sum(qty * price).
# 2. A plain Python loop that accumulates qty[i] * price[i].
# Print both totals and whether they are equal.

# your code here

# %% [markdown]
# ## Problem 4: Normalize to 0..1
#
# ```
# normalized: [0.5  0.   1.   0.33]
# ```

# %%
scores = np.array([50, 20, 80, 40])

# TODO (no loop): rescale the array so the smallest becomes 0 and the largest
# becomes 1, using (x - min) / (max - min) on the whole array at once.
# Print the result rounded to two decimals with np.round(..., 2).

# your code here

# %% [markdown]
# ## Problem 5: A DataFrame
#
# ```
#     name  score team
# 0    Ada     91    A
# 1   Alan     72    B
# 2  Grace     85    A
# 3    Kay     60    B
#
# scores: [91, 72, 85, 60]
#
#     name  score team
# 0    Ada     91    A
# 2  Grace     85    A
# ```

# %%
df = pd.DataFrame({
    "name": ["Ada", "Alan", "Grace", "Kay"],
    "score": [91, 72, 85, 60],
    "team": ["A", "B", "A", "B"],
})

# TODO: print the whole DataFrame; print the score column as a list;
# then print only the rows where score >= 85.

# your code here

# %% [markdown]
# ## Problem 6: Derived column and group
#
# ```
#     name  score team  passed
# 0    Ada     91    A    True
# 1   Alan     72    B    True
# 2  Grace     85    A    True
# 3    Kay     60    B   False
#
# team
# A    88.0
# B    66.0
# Name: score, dtype: float64
# ```

# %%
df = pd.DataFrame({
    "name": ["Ada", "Alan", "Grace", "Kay"],
    "score": [91, 72, 85, 60],
    "team": ["A", "B", "A", "B"],
})

# TODO: add a boolean column "passed" that is True when score >= 70; print the table.
# Then print the mean score per team (groupby "team", then the "score" mean).

# your code here

# %% [markdown]
# ## Problem 7: Clean a messy table
#
# ```
#   city  sales  visits  per_visit
# 0    A  100.0      10       10.0
# 2    C  250.0      25       10.0
# ```

# %%
raw = pd.DataFrame({
    "city": ["A", "B", "C", "D"],
    "sales": [100.0, np.nan, 250.0, 80.0],
    "visits": [10, 5, 25, 8],
})

# TODO: drop rows that have a missing value, keep only rows where sales > 90,
# then add a "per_visit" column = sales / visits. Print the cleaned table.
# Tip: call .copy() after filtering so the new column assigns cleanly.

# your code here

# %% [markdown]
# ## Problem 8: Top category
#
# ```
# category
# books    10
# food     50
# toys     40
# Name: amount, dtype: int64
#
# top category: food with 50
# ```

# %%
sales = pd.DataFrame({
    "category": ["food", "toys", "food", "books", "toys"],
    "amount": [20, 15, 30, 10, 25],
})

# TODO: total the amount per category (groupby "category", then sum "amount"); print it.
# Then print which category has the highest total, and that total.
# Hint: a grouped Series has .idxmax() (the label of the max) and .max() (the value).

# your code here
