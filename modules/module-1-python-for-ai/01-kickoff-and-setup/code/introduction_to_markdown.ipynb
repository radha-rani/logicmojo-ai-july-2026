# %% [markdown]
# This is an example of simple texts in markdown.

# %% [markdown]
# # This is heading-1 (Title)
#
# ## This is heading-2
#
# ### This is heading-3
#
# #### This is heading-4

# %% [markdown]
# ## Numbered list
#
# 1. item-1
# 1. item-2
# 1. item-2.5
# 1. item-3

# %% [markdown]
# ## Bullet list
#
# - item-1
# - item-2
# - item-3

# %% [markdown]
# ## Nested lists
#
# 1. Python for AI
#     - Basics of python
#     - OOP in python
#     - Numpy and Pandas
#     - API calls
# 2. ML and DL fundamentals
#     - what is ML?
#     - what is loss function
#     - mathemticas for ML
#     - Deep learning in pytorch
#     - hands on

# %% [markdown]
# ## Mathematical formula using Latex
#
# $$ E = mc^2 $$
#
# $$ x = \frac{-b \pm \sqrt{b^2-4ac}}{2a} $$

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# In jupyter notebook (.ipynb files)
#
# - Esc + 'm' -> converts code cell to markdown cell
# - Esc + 'y' -> converts markdown cell to code cell
