# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/skarma91/logicmojo-ai-july-2026/blob/main/modules/module-3-nlp-to-transformers/04-pretrained-transformers/micro-assignment/assignment.ipynb)
#
# # Micro-assignment 3.4: Using pretrained transformers
#
# Fill in each cell. Match the expected output in `README.md`. These need no downloads.

# %% [markdown]
# ### Problem 1: Task to pipeline name

# %%
mapping = {"sentiment": "sentiment-analysis", "generate": "text-generation", "embed": "feature-extraction"}
tasks = ["sentiment", "embed"]
# Print the pipeline names for the given tasks.
# your code here
pipeline_names = [mapping[task] for task in tasks]
print(pipeline_names)
# Out:
# ['sentiment-analysis', 'feature-extraction']

# %% [markdown]
# ### Problem 2: Why load the matching tokenizer

# %%
# Print one line on why the tokenizer and model must be the matching pair.
# your code here
print("the model learned what each token id means; a mismatched tokenizer assigns different ids, so the input is meaningless to the model. Load the tokenizer and model by the same name")
# Out:
# the model learned what each token id means; a mismatched tokenizer assigns different ids, so the input is meaningless to the model. Load the tokenizer and model by the same name

# %% [markdown]
# ### Problem 3: A padded batch's shape

# %%
lengths = [4, 6, 5]
# Print the shape of the padded batch as (num_texts, max_len).
# your code here

num_texts = len(lengths)
max_len = max(lengths)

print(f"batch shape: ({num_texts}, {max_len})")
# Out:
# batch shape: (3, 6)

# %% [markdown]
# ### Problem 4: Inference settings

# %%
# Print one line on what model.eval() and torch.no_grad() do for inference.
# your code here
print("model.eval() and torch.no_grad(): eval switches layers like dropout to scoring mode, and no_grad skips gradient tracking for a faster forward pass")
# Out:
# model.eval() and torch.no_grad(): eval switches layers like dropout to scoring mode, and no_grad skips gradient tracking for a faster forward pass

# %% [markdown]
# ### Problem 5: Tokens vs words

# %%
s = "the cat sat"
# Print the number of whitespace words.
# your code here
s = "the cat sat"

words = len(s.split())
print(f"words: {words}")
# Out:
# words: 3

# %% [markdown]
# ### Problem 6: Why use a pretrained model

# %%
# Print one line on why we use a pretrained model instead of training our own.
# your code here
print("pretrained models already learned language from huge corpora, so you get strong results without the data, compute, or time to train one yourself")
# Out:
# pretrained models already learned language from huge corpora, so you get strong results without the data, compute, or time to train one yourself
